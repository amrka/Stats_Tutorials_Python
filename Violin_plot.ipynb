# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
tips = sns.load_dataset("tips")

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
tips[1:2]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
ax = sns.swarmplot(x="sex", y="total_bill", data=tips, color="white", edgecolor="gray")

# %%
import pandas as pd

# %%
>>> d = {'col1': [1, 2], 'col2': [3, 4]}
>>> df = pd.DataFrame(data=d)
>>> df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
functional_connectivity = { 'Transgenic' : [-2.24799965156629, 0.955995335455424, 1.16141905168843, -0.0401454660974349, -9.06412062543982, -8.58443949102477, -9.39076094589255, 0.671200720760176, -4.32953011088730, -0.935835913938348, -1.10770759498278, -5.42096125937258, 0.498407039446797, -11.2259739794093, None ,None ],'Control': [-5.42678216440428,-0.157828662237090,1.99284180323099,6.99464542516131,6.64790365136491,4.50468286328809,1.04720166792946,1.38701156168665,4.95734933361690,-0.120937589406629,3.44526814344616,-0.688359457136989,17.6678322935686,2.40002514637505,0.459978243159535,4.52376341745122]}

# %%
FC = pd.DataFrame(data=functional_connectivity)

# %%
FC
# Out:
#       Control  Transgenic
# 0   -5.426782   -2.248000
# 1   -0.157829    0.955995
# 2    1.992842    1.161419
# 3    6.994645   -0.040145
# 4    6.647904   -9.064121
# 5    4.504683   -8.584439
# 6    1.047202   -9.390761
# 7    1.387012    0.671201
# 8    4.957349   -4.329530
# 9   -0.120938   -0.935836
# 10   3.445268   -1.107708
# 11  -0.688359   -5.420961
# 12  17.667832    0.498407
# 13   2.400025  -11.225974
# 14   0.459978         NaN
# 15   4.523763         NaN

# %%
my_pal = {'Transgenic': 'r', 'Control': 'k'}
ax = sns.violinplot(data=FC, inner=None, palette=my_pal)
ax = sns.swarmplot(data=FC, color="white", edgecolor="gray")
ax.grid(False)
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

ax = sns.set_style("ticks")
ax = sns.despine(offset=10, trim=True);
